# %% [markdown]
# # Numeric Data Type

# %%
type(-12+100)
# Out:
# int

# %%
type(12+10.23)
# Out:
# float

# %%
type(12+3j)
# Out:
# complex

# %%
type(1>5)
# Out:
# bool

# %% [markdown]
# # Sequence type data type

# %%
#String
'Single quote'
# Out:
# 'Single quote'

# %%
"Double quote"
# Out:
# 'Double quote'

# %%
""" hello im typing out my fundamentals,
 so i can just go back to here to revise"""
# Out:
# ' hello im typing out my fundamentals,\n so i can just go back to here to revise'

# %% [markdown]
# # Lists(imp)

# %%
list=[1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Tuple

# %%
tuple=(1,2,3,4,5,6)
print(tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# # Sets

# %%
daily_pints = {1,2,3,35,6,7,2,3,6,2,7}
print(daily_pints)
# Out:
# {1, 2, 3, 35, 6, 7}

# %% [markdown]
# # Dictionary

# %%
#key value pair
dict = {'name':'Alex Freberg','weekly intake':5,'fav icecreams':'chocolate'}
print(dict)
# Out:
# {'name': 'Alex Freberg', 'weekly intake': 5, 'fav icecreams': 'chocolate'}
